# %% [markdown]
# <a href="https://colab.research.google.com/github/shaziyakhann/shaziyakhann/blob/main/qn3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Replace with your OpenRouteService API key
ORS_API_KEY = '5b3ce3597851110001cf6248ac9bd7689924491b812a74de277c35ca'

def get_geocode(location):
    geocode_url = f"https://api.openrouteservice.org/geocode/search?api_key={ORS_API_KEY}&text={location}"
    response = requests.get(geocode_url)

    if response.status_code != 200:
        raise Exception(f"Error fetching geocode: {response.status_code}")

    data = response.json()
    if 'features' not in data or len(data['features']) == 0:
        raise Exception("No geocoding results found.")

    coords = data['features'][0]['geometry']['coordinates']
    return coords

def get_traffic_data(start, end):
    try:
        start_coords = get_geocode(start)
        end_coords = get_geocode(end)
    except Exception as e:
        return {'error': str(e)}

    routing_url = f"https://api.openrouteservice.org/v2/directions/driving-car"
    headers = {
        'Authorization': ORS_API_KEY,
        'Content-Type': 'application/json'
    }
    body = {
        "coordinates": [start_coords, end_coords]
    }

    response = requests.post(routing_url, json=body, headers=headers)

    if response.status_code != 200:
        return {'error': f"Error fetching route: {response.status_code}"}

    route_data = response.json()

    if 'routes' not in route_data:
        return {'error': 'No routes found'}

    route = route_data['routes'][0]
    summary = route['summary']

    traffic_info = {
        'start_address': start,
        'end_address': end,
        'distance': summary['distance'] / 1000,  # convert to km
        'duration': summary['duration'] / 60,  # convert to minutes
        'polyline': route['geometry']
    }

    return traffic_info

def display_traffic_info(start, end):
    traffic_info = get_traffic_data(start, end)
    if 'error' in traffic_info:
        print("Error:", traffic_info['error'])
    else:
        print("Traffic Information:")
        print(f"Start Address: {traffic_info['start_address']}")
        print(f"End Address: {traffic_info['end_address']}")
        print(f"Distance: {traffic_info['distance']} km")
        print(f"Duration: {traffic_info['duration']} minutes")
        print("Polyline:", traffic_info['polyline'])

# Hardcoded start and end locations
start = "New York, NY"
end = "Los Angeles, CA"
display_traffic_info(start, end)
# Out:
# Traffic Information:
# Start Address: New York, NY
# End Address: Los Angeles, CA
# Distance: 4500.8268 km
# Duration: 2694.7033333333334 minutes
# Polyline: m{hwFtlnbME?eALOBuD`@kCZsApE_A~CWx@uAvEsApEy@pC_@lAeAlDUr@m@vBkAzDoAhEGPc@~AYNyDtAwGjCoCfAqHtCUHu@ZmDrASHsAj@e@PsAj@_@PyEjBsAd@WP}@b@e@VkHfDkzA~q@qDbBMFi@VwA~@]d@[z@u@xCA^w@zCy@bDOf@KTy@pA}A~BqArBiBrCwAxBgBnCeBjCW`@_AzAcBhC}@xAg@v@g@Fg@IoCw@}Bu@WjFGZS|@Wl@QX]ZQJ_@HeBKU@]Nm@\WXOTM\K^M`AqC`m@aEdb@gDp_@}Ap`@IjAaBlLUpAYz@o@vA}BbEy@fAc@x@_AdCGZCt@QlEGdAEx@Cj@Cd@G~AATATEr@Ct@E`AMrCE|@A^ANG~@SzEG~BDhBFz@bAbNp@xFb@xCFnAAp@Ex@Gl@Ov@c@pAy@zAk@x@wc@pi@s@dAy@dB[t@q@tBe@tBWvAQdB]bDKvBGv@Qj@k@O[ScBaBkA_Ae@YeAg@oA[sH_BYGkAUg@KaASw@Om@MuA[k@OqCu@qCs@aAa@}BaAwCoAoDgB{@o@}@w@}A_ByCkDa@a@qDoCkLaIaAs@UMgCgBc@YiAw@kBuA}@{@aKuK_ByAsFwD_IaFaBcAe@YeAq@i@]uBsAyA{@{BuAcDsBg@]WSgBkAqEaDy@m@eEuCgBmA_BkAaB}@aAm@o@i@q@e@cAk@cAk@{@_@_AQm@A_AJSFm@b@oAdBORsAfBcAjAeBdB}AhAoAr@eAh@gBl@oAZkRhEoANoQxDkCn@sA^kCbAwBdA{@f@qBrA_Ar@cBxAu@t@cBpB_BvBkPjWaJrNaBbCsJ~N_D`F_JzMi[xe@oAhB_A~AiF~HwA~Bw@xAw@zAmAhC_DvHeEdL{EnMk@dB{@xCuAfGi@fDUnBQrBOpBOjDIlD@pCDbCLlDbA`Sn@xMFnC?rBErBGtAMnBMrAWnB[jB_@lBc@dBSt@{@tCqNza@M^u@vBkA~C_AjCgAdCmIxQwC`GmDjH_ChEw@xAaCdEkDfGiC`FkAbC_D|GmBrEkBxEaCtG_@`AoAlDs@rBmF`Oa@fAg@xAUn@gB~EUn@mAhDcC|G_AhCm@`Bw@zBm@bBgGpPSj@oDzJUn@k@`BcArCWr@k@~Am@`BcD~ISl@qBtFWp@Wn@oDpJa@fASf@Ob@c@fAa@dAIVgAvCqAjDoDlJs@hBc@lAmA~CWp@oDpJOb@iGdPgBzDkC~EuCpE_CzCeBpBkCjC}TfSu@p@oTvR{@t@SR_Ax@aIfHu@p@sAhAuBzAoAr@y@b@qAh@yAh@aBb@yBd@sC\wAHsH`@aC`@oCj@oAZcBl@aBt@oC|A_BbAoAdAcCtBeAtA_EjEOP}BdDgB|Cy@zAqFdL{@jBwAxCg@tB}ArF_@jBsAbJi@jC_@tAc@vAw@fBqC|Fg@fA_@|@{A|EaAhEk@vBa@jAgAxB}AvBqKlKYZGHqCdD}BbD}AdCU^c@x@OXc@v@}CzF_@r@gE`IuAhCeAnBYj@_BxC_@r@aAfBoB|CcAvAe@j@k@r@kHtGcEvDYT[ZiClCaEnF{CrGeBbEUr@}@tCO~@uAxF]lBo@pEi@vFIfAS~BIbAMxAUvCEZS`CUnCWvCC`@w@zJ_@rGYrGKxE?FCtA?hB?v@L~DBd@L`EDnAJtCNxEJnDDlB?fAGdAOhAI`@W~@u@lB]dAOx@Ez@@~@Ff@VdAXp@^n@NRb@b@lBrAt@t@^l@JVjApD\tAXbBJtAFrAAzBe@|OA~@B`BRlFNbEDjAJfCN|DXxG\rEJ|@VpBx@xENp@jCxKdAnEVfAr@rC|CtMxBxIl@hCpAdFJd@v@fCN`@Pj@v@nCTr@dAtCx@hCpBhFvAlDbAbC\|@FNjCrG~@`CzArDXp@d@jAJVj@vAJTr@fBd@vAb@fApArCfBnE`C~F|AhD~@bBfArBt@rAlBlD^r@pArB~BtDPXXb@j@v@j@t@h@p@d@l@t@`A`AlAf@l@bBjBnAtAhCtCv@z@vCdDdCtCb@d@p@x@bAhA~@fAb@n@x@nAjAhBx@rA`@z@`@r@R`@l@jAP\~@hBRj@hAxCXt@Pd@N`@\~@|AbFNf@pAlDx@fBpCdGhAfCv@~A`@z@~@pBd@dAZl@LZb@~@vAlCbBxCvAbCtCtEpBtCdJ~Lp@jAVj@^|@\dAXjARhAJz@b@zEBf@DpAJfFFxCD`C@f@FnDFrB@h@BpABbADrC@h@JjFBp@LrG@d@@d@BlABzA@vB@j@BjADnBLhEBt@Bv@DhCBbAB|A@r@PlIDhBBjA@h@@bA@p@@vA@rBDfBH|E@TDhAFbBBpC?dC@p@?|@Ah@GpCGbBCf@Ex@GfAGbAI~@YjDg@jEIf@Kt@CPKv@YlBKn@QrAMt@SvAYjBi@~DG\e@`DE^YnBG^Mx@UhBuBrNaBdLo@tEO~AW~DIrBEfAItBCn@GtBIlBKnCIzBKtCGfBCx@I|Bc@pMqAz]GxAMpDA^Cn@GzAAl@EhAEnAAZEz@Ad@M~CCdAG~AEbAAZCp@ItBCv@GbBG~AGvAE\Q|E?l@[nIGrBE|@YjHCp@IvCGdBGzAIhBOnCC\SlBCJGh@SrAUdBiEb[g@`Cc@zA_AfCi@tAYt@}EfMeAtCaBbEmCbHkAlD]pA{@xCYvAYrASvAy@zFa@jD]jCi@jEy@fG_@zCuAvKYpBs@tD}@xDWnAETMl@aBrIeC~LWpAQx@cAxE_@`BiA|Ew@~CK\{@fDwCjLc@|AWjA{@pEKd@o@xCu@xCCD{AdG_@|Ao@fBo@bBcBhEm@|A}AzDs@rAQZiAdC}IbUu@xBUt@i@hB}@tDYrAQn@m@xCWrA_@tB_@rBm@`Cg@`BSb@Sf@i@z@s@jAu@`AuDlEk@v@q@hAYj@Sb@_BfDmAvCm@jBUbAGVMl@YnBQnAmA`KIt@Il@In@cDhX]hCa@dDe@rBe@xAc@hAoAfC]h@aBrBkAdAiC~B}BhCQRaAvAaAhB{@pBkDxIQd@}AtCe@v@mAbBsAzAmAjAcAx@_CbCMJoAbAwAtAq@t@eOfQqA`B{CbE}AzBiDlFaBrC}@|AqDfHwGdNmApCWn@qArDq@rBeAtDu@|C_@jBo@lDu@fFk@hFUnCSjDOhDKfFAvBP|b@BlEnAteCRl_@BhEV~c@BtB`@du@RjIj@xKDr@fAtLRrB`AtJJdAbBfPJhAx@zHZfDZdELpCFzBBn@BrC@zDApAKfDGnB[`FyBf[YfEKnDEjCAnB@dFJpDLlCXbEPpBb@rDb@hC|@~ExCjOPz@^hBtJrf@d@zBR`Af@dCr_@rlBzHh`@Z|ArFtXlRl`Ap@|D|@fH\lDZ~ETtFJ`G?fEAnAa@~RGhDKfD]vPGhBEhBEdD?r@?hEJbFLbELrB`@vFTxBd@|Dn@|DdExUZlBZ`C^lDT~B\`FRzEJjE@zBAbEUdPM|IEbDWfPK~GIvEAh@An@GvEAf@ATs@jh@WnNErAQtC]jDe@~C]lBs@`Do@vBw@zBs@bBaArB}AnCcB~BwAbBkBdB_BpAeBhAw@d@iCpAqOhH{BdAqDpBsBnAeCbBiA|@qB~AeDxCkDpDsDlEy@hAwChEiAhBwB|D{@~AgBvDgAjCuBtFkB|FwAfFaBhH}@xEeA|G}@vH_@hE_@lGQjDKhDKhH?lEFfGDrBhBvj@FbDArBGhBKlBSdB[hB_@dBc@~Am@bBcA~BsA`D}FxMcAjCk@dBs@nC_@lBa@bDQrBItBElC@~CBhMAxBChBSpE[dDk@vDy@xDc@|A_AnCsArC}@vAm@v@s@x@iAbAmA|@oAt@qLnFuBdAmBvAy@v@eAlAiAbB{@|AgArCm@vBm@rCWxBQpBI`CApA@dBHpBNrBb@`D^lBhC~L~@`FXxBZ|Cv@zJh@nGXxBZfB^~An@rBxAhDp@lAv@jAb@j@`AfAdDbDfFxEfBrBtApBXh@n@tAd@nAd@|Ad@pBVvANnANjBJxCAdDElAShCMfA}BxOgAzHKdASlCGnBApCB~BDhAr@xN ...
