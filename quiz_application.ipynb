# %% [markdown]
# <a href="https://colab.research.google.com/github/shaziyakhann/API_integration_python/blob/main/quiz_application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# ✅ 60 general knowledge / science / tech questions
quiz_questions = [
    {"question": "What is the capital of India?", "answer": "New Delhi"},
    {"question": "Who invented Python?", "answer": "Guido van Rossum"},
    {"question": "What is the value of Pi (upto 2 decimal places)?", "answer": "3.14"},
    {"question": "What is the boiling point of water in Celsius?", "answer": "100"},
    {"question": "Which planet is closest to the Sun?", "answer": "Mercury"},
    {"question": "In which year did India gain independence?", "answer": "1947"},
    {"question": "Which element has the chemical symbol 'O'?", "answer": "Oxygen"},
    {"question": "How many continents are there?", "answer": "7"},
    {"question": "What does RAM stand for?", "answer": "Random Access Memory"},
    {"question": "Who painted the Mona Lisa?", "answer": "Leonardo da Vinci"},
    {"question": "What is the largest mammal?", "answer": "Blue Whale"},
    {"question": "Which country is known as the Land of Rising Sun?", "answer": "Japan"},
    {"question": "Who discovered gravity?", "answer": "Isaac Newton"},
    {"question": "What is H2O?", "answer": "Water"},
    {"question": "What gas do plants absorb?", "answer": "Carbon dioxide"},
    {"question": "Which organ pumps blood in the human body?", "answer": "Heart"},
    {"question": "How many bones are in the human body?", "answer": "206"},
    {"question": "Who is the father of the nation (India)?", "answer": "Mahatma Gandhi"},
    {"question": "What is the smallest prime number?", "answer": "2"},
    {"question": "Which planet is known as the Red Planet?", "answer": "Mars"},
    {"question": "Which animal is known as the Ship of the Desert?", "answer": "Camel"},
    {"question": "What is the square root of 144?", "answer": "12"},
    {"question": "What is the chemical formula for salt?", "answer": "NaCl"},
    {"question": "Who was the first President of India?", "answer": "Dr. Rajendra Prasad"},
    {"question": "Which is the longest river in the world?", "answer": "Nile"},
    {"question": "What is the speed of light?", "answer": "299792458"},
    {"question": "How many players are there in a cricket team?", "answer": "11"},
    {"question": "Which planet has rings?", "answer": "Saturn"},
    {"question": "Which Indian city is known as the Silicon Valley of India?", "answer": "Bangalore"},
    {"question": "What is 15 multiplied by 4?", "answer": "60"},
    {"question": "Who developed the theory of relativity?", "answer": "Albert Einstein"},
    {"question": "How many letters are there in the English alphabet?", "answer": "26"},
    {"question": "Which programming language is named after a snake?", "answer": "Python"},
    {"question": "What is the capital of France?", "answer": "Paris"},
    {"question": "Which metal is liquid at room temperature?", "answer": "Mercury"},
    {"question": "What is the full form of CPU?", "answer": "Central Processing Unit"},
    {"question": "How many sides does a hexagon have?", "answer": "6"},
    {"question": "What is 1000 divided by 25?", "answer": "40"},
    {"question": "Which animal is known as the King of the Jungle?", "answer": "Lion"},
    {"question": "What is the currency of the USA?", "answer": "Dollar"},
    {"question": "How many hours are there in a day?", "answer": "24"},
    {"question": "What comes after Tuesday?", "answer": "Wednesday"},
    {"question": "Which is the largest ocean in the world?", "answer": "Pacific"},
    {"question": "Who wrote 'Hamlet'?", "answer": "Shakespeare"},
    {"question": "What is the capital of Tamil Nadu?", "answer": "Chennai"},
    {"question": "How many legs does a spider have?", "answer": "8"},
    {"question": "What is the national bird of India?", "answer": "Peacock"},
    {"question": "How many zeros are there in one lakh?", "answer": "5"},
    {"question": "Which gas is used in balloons?", "answer": "Helium"},
    {"question": "What is the fastest land animal?", "answer": "Cheetah"},
    {"question": "Which instrument is used to measure temperature?", "answer": "Thermometer"},
    {"question": "What is the capital of Karnataka?", "answer": "Bangalore"},
    {"question": "Which device is used to input text?", "answer": "Keyboard"},
    {"question": "What shape has three sides?", "answer": "Triangle"},
    {"question": "Which is the largest continent?", "answer": "Asia"},
    {"question": "What is the process of water turning into vapor?", "answer": "Evaporation"},
    {"question": "Who is known as the Missile Man of India?", "answer": "APJ Abdul Kalam"},
    {"question": "Which month comes after September?", "answer": "October"},
    {"question": "How many days are there in a leap year?", "answer": "366"},
    {"question": "What is the main source of energy for Earth?", "answer": "Sun"},
    {"question": "What is 9 squared?", "answer": "81"},
    {"question": "Which city is the Taj Mahal located in?", "answer": "Agra"}
]

# Shuffle questions
random.shuffle(quiz_questions)

# Start quiz
score = 0
print("📘 Welcome to the 60-Question Python Quiz!\n")

for i, q in enumerate(quiz_questions, 1):
    print(f"Q{i}: {q['question']}")
    answer = input("Your answer: ").strip()

    if answer.lower() == q["answer"].lower():
        print("✅ Correct!\n")
        score += 1
    else:
        print(f"❌ Incorrect. Correct answer: {q['answer']}\n")

# Final result
print(f"🎉 You completed the quiz!")
print(f"📝 Score: {score}/{len(quiz_questions)}")
print(f"📊 Percentage: {(score / len(quiz_questions)) * 100:.2f}%")
# Out:
# 📘 Welcome to the 60-Question Python Quiz!
#
# Q1: What does RAM stand for?
# Your answer: random access memory
# ✅ Correct!
#
# Q2: Which programming language is named after a snake?
# Your answer: python
# ✅ Correct!
#
# Q3: Which is the largest continent?
# Your answer: asia
# ✅ Correct!
#
# Q4: How many players are there in a cricket team?
# Your answer: 6
# ❌ Incorrect. Correct answer: 11
#
# Q5: Who developed the theory of relativity?
# Your answer: albert eistein
# ❌ Incorrect. Correct answer: Albert Einstein
#
# Q6: What is the value of Pi (upto 2 decimal places)?
# Your answer: 3.14
# ✅ Correct!
#
# Q7: What is the process of water turning into vapor?
# Your answer: evaporation
# ✅ Correct!
#
# Q8: What comes after Tuesday?
# Your answer: wednesday
# ✅ Correct!
#
# Q9: What is the fastest land animal?
